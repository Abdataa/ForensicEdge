# %%
import os
os.chdir('/content/drive/MyDrive/ForensicEdge')

# %%
# !pip install --upgrade ipython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.7/625.7 kB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.12.0 which is incompatible.
# ...

# %%
# %load_ext autoreload
# %autoreload 2

import train_siamese  # Now, changes to the .py file will update here automatically
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_401/2824126355.py in <cell line: 0>()
#       2 get_ipython().run_line_magic('autoreload', '2')
#       3
# ----> 4 import train_siamese  # Now, changes to the .py file will update here automatically
#
# ModuleNotFoundError: No module named 'train_siamese'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !git pull
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 513 bytes | 1024 bytes/s, done.
# From https://github.com/Abdataa/ForensicEdge
#    72f4821..7a5698f  main       -> origin/main
# Updating d1f0b47..7a5698f
# error: Your local changes to the following files would be overwritten by merge:
# 	ai_engine/colab_vs.ipynb
# Please commit your changes or stash them before you merge.
# Aborting

# %%
# !python ai_engine/preprocessing/restructure_socofing.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ForensicEdge/ai_engine/preprocessing/restructure_socofing.py", line 8, in <module>
#     RAW_PATH = Base/"datasets/raw/fingerprints/SOCOFing/Real"
#                ^^^^
# NameError: name 'Base' is not defined. Did you mean: 'BASE'?

# %%
# !python -m ai_engine.preprocessing.restructure_socofing
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/drive/MyDrive/ForensicEdge/ai_engine/preprocessing/restructure_socofing.py", line 8, in <module>
#     RAW_PATH = Base/"datasets/raw/fingerprints/SOCOFing/Real"
#                ^^^^
# NameError: name 'Base' is not defined. Did you mean: 'BASE'?

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 8 (delta 6), reused 7 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (8/8), 1.49 KiB | 1024 bytes/s, done.
# From https://github.com/Abdataa/ForensicEdge
#  * branch            main       -> FETCH_HEAD
#    0978562..c27bcfc  main       -> origin/main
# Updating 0978562..c27bcfc
# Fast-forward
#  ai_engine/preprocessing/restructure_socofing.py | 4 ++--
#  ai_engine/training/train_siamese.py             | 6 ++++--
#  2 files changed, 6 insertions(+), 4 deletions(-)

# %%
# !python -m ai_engine.preprocessing.restructure_socofing
# Out:
# Total identities: 1
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/drive/MyDrive/ForensicEdge/ai_engine/preprocessing/restructure_socofing.py", line 34, in <module>
#     shutil.copy(src, dst)
#   File "/usr/lib/python3.12/shutil.py", line 435, in copy
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#   File "/usr/lib/python3.12/shutil.py", line 260, in copyfile
#     with open(src, 'rb') as fsrc:
#          ^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Real/Real'

# %%
from pathlib import Path

base = Path("/content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing")

for path in base.rglob("Real"):
    print(f"\nChecking: {path}")
    items = list(path.iterdir())
    print(f"Total items: {len(items)}")

    # Show first few items
    for item in items[:5]:
        print("  ", item.name, "(DIR)" if item.is_dir() else "(FILE)")
# Out:
# Checking: /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Real
# Total items: 1
#    Real (DIR)
#
# Checking: /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Real/Real
# Total items: 6000
#    551__F_Left_index_finger.BMP (FILE)
#    551__F_Left_little_finger.BMP (FILE)
#    551__F_Left_middle_finger.BMP (FILE)
#    551__F_Left_ring_finger.BMP (FILE)
#    551__F_Left_thumb_finger.BMP (FILE)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5989/3131072210.py in <cell line: 0>()
#       3 base = Path("/content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing")
#       4
# ----> 5 for path in base.rglob("Real"):
#       6     print(f"\nChecking: {path}")
#       7     items = list(path.iterdir())
#
# /usr/lib/python3.12/pathlib.py in rglob(self, pattern, case_sensitive)
# ...

# %%
from pathlib import Path
import shutil

outer = Path("/content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Real")
inner = outer / "Real"

# Move all files from inner → outer
for file in inner.iterdir():
    if file.is_file():
        shutil.move(str(file), str(outer / file.name))

print("Files moved successfully.")

# Remove the now-empty inner folder
inner.rmdir()

print("Empty inner 'Real' folder removed.")
# Out:
# Files moved successfully.
# Empty inner 'Real' folder removed.

# %%
from pathlib import Path

base = Path("/content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing")

for path in base.rglob("*"):
    if path.is_dir():
        num_files = len([f for f in path.iterdir() if f.is_file()])
        num_dirs  = len([f for f in path.iterdir() if f.is_dir()])

        print(f"{path}")
        print(f"   Files: {num_files}, Folders: {num_dirs}")
# Out:
# /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Real
#    Files: 6000, Folders: 0
# /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Altered
#    Files: 0, Folders: 1
# /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Altered/Altered
#    Files: 0, Folders: 3
# /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Altered/Altered/Altered-Easy
#    Files: 17931, Folders: 0
# /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Altered/Altered/Altered-Hard
#    Files: 14272, Folders: 0
# /content/drive/MyDrive/ForensicEdge/ai_engine/datasets/raw/fingerprints/SOCOFing/Altered/Altered/Altered-Medium
#    Files: 17067, Folders: 0

# %%
# Step 1 — restructure SOCOFing into identity folders
# !python -m ai_engine.preprocessing.restructure_socofing
# Out:
# Total identities: 600

# %%
from pathlib import Path

BASE = Path("/content/drive/MyDrive/ForensicEdge/ai_engine/datasets/processed/SOCOFing")

identities = [d for d in BASE.iterdir() if d.is_dir()]

print("Total identity folders:", len(identities))

all_counts = []

for identity in identities:
    num_files = len([f for f in identity.iterdir() if f.is_file()])
    all_counts.append(num_files)

print("\nMin images per identity:", min(all_counts))
print("Max images per identity:", max(all_counts))
print("Average images per identity:", sum(all_counts)/len(all_counts))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ForensicEdge
# Out:
# /content/drive/MyDrive/ForensicEdge

# %%
# !git pull
# Out:
# Updating d1f0b47..0a980f3
# error: Your local changes to the following files would be overwritten by merge:
# 	ai_engine/colab_vs.ipynb
# Please commit your changes or stash them before you merge.
# Aborting

# %%
# !python ai_engine/training/train_siamese.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ForensicEdge/ai_engine/training/train_siamese.py", line 88, in <module>
#     from ai_engine.models.siamese_network    import SiameseNetwork
#   File "/content/drive/MyDrive/ForensicEdge/ai_engine/models/siamese_network.py", line 5, in <module>
#     from cnn_feature_extractor import FingerprintCNN
# ModuleNotFoundError: No module named 'cnn_feature_extractor'
